# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp /content/drive/My\ Drive/Colab\ Notebooks/learning.datascience/test.csv .
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
nfl_frame = pd.read_csv('test.csv', sep='\t')

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  ...   Pct.  First NFL Season   Division
# 0     1        Dallas Cowboys    914  ...  0.572              1960   NFC East
# 1     2     Green Bay Packers  1,368  ...  0.567              1921  NFC North
# 2     3  New England Patriots    916  ...  0.564              1960   AFC East
# 3     4         Chicago Bears  1,402  ...  0.563              1920  NFC North
# 4     5      Baltimore Ravens    384  ...  0.559              1996  AFC North
# 5     6        Miami Dolphins    832  ...  0.552              1966   AFC East
#
# [6 rows x 9 columns]

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Division'],
#       dtype='object')

# %%
nfl_frame.Team
# Out:
# 0          Dallas Cowboys
# 1       Green Bay Packers
# 2    New England Patriots
# 3           Chicago Bears
# 4        Baltimore Ravens
# 5          Miami Dolphins
# Name: Team, dtype: object

# %%
nfl_frame[['Team', 'First NFL Season']]
# Out:
#                    Team  First NFL Season
# 0        Dallas Cowboys              1960
# 1     Green Bay Packers              1921
# 2  New England Patriots              1960
# 3         Chicago Bears              1920
# 4      Baltimore Ravens              1996
# 5        Miami Dolphins              1966

# %%
nfl_frame['First NFL Season']
# Out:
# 0    1960
# 1    1921
# 2    1960
# 3    1920
# 4    1996
# 5    1966
# Name: First NFL Season, dtype: int64

# %%
DataFrame(nfl_frame, columns=['Team', 'First NFL Season'])
# Out:
#                    Team  First NFL Season
# 0        Dallas Cowboys              1960
# 1     Green Bay Packers              1921
# 2  New England Patriots              1960
# 3         Chicago Bears              1920
# 4      Baltimore Ravens              1996
# 5        Miami Dolphins              1966

# %%
DataFrame(nfl_frame, columns=['Team', 'First NFL Season', 'Stadium'])
# Out:
#                    Team  First NFL Season  Stadium
# 0        Dallas Cowboys              1960      NaN
# 1     Green Bay Packers              1921      NaN
# 2  New England Patriots              1960      NaN
# 3         Chicago Bears              1920      NaN
# 4      Baltimore Ravens              1996      NaN
# 5        Miami Dolphins              1966      NaN

# %%
nfl_frame.head()
# Out:
#    Rank                  Team     GP  ...   Pct.  First NFL Season   Division
# 0     1        Dallas Cowboys    914  ...  0.572              1960   NFC East
# 1     2     Green Bay Packers  1,368  ...  0.567              1921  NFC North
# 2     3  New England Patriots    916  ...  0.564              1960   AFC East
# 3     4         Chicago Bears  1,402  ...  0.563              1920  NFC North
# 4     5      Baltimore Ravens    384  ...  0.559              1996  AFC North
#
# [5 rows x 9 columns]

# %%
nfl_frame.head(3)
# Out:
#    Rank                  Team     GP  ...   Pct.  First NFL Season   Division
# 0     1        Dallas Cowboys    914  ...  0.572              1960   NFC East
# 1     2     Green Bay Packers  1,368  ...  0.567              1921  NFC North
# 2     3  New England Patriots    916  ...  0.564              1960   AFC East
#
# [3 rows x 9 columns]

# %%
nfl_frame.tail()
# Out:
#    Rank                  Team     GP  ...   Pct.  First NFL Season   Division
# 1     2     Green Bay Packers  1,368  ...  0.567              1921  NFC North
# 2     3  New England Patriots    916  ...  0.564              1960   AFC East
# 3     4         Chicago Bears  1,402  ...  0.563              1920  NFC North
# 4     5      Baltimore Ravens    384  ...  0.559              1996  AFC North
# 5     6        Miami Dolphins    832  ...  0.552              1966   AFC East
#
# [5 rows x 9 columns]

# %%
nfl_frame.tail(3)
# Out:
#    Rank              Team     GP  Won  ...  Tied   Pct.  First NFL Season   Division
# 3     4     Chicago Bears  1,402  769  ...    42  0.563              1920  NFC North
# 4     5  Baltimore Ravens    384  214  ...     1  0.559              1996  AFC North
# 5     6    Miami Dolphins    832  457  ...     4  0.552              1966   AFC East
#
# [3 rows x 9 columns]

# %%
nfl_frame.iloc[3]
# Out:
# Rank                            4
# Team                Chicago Bears
# GP                          1,402
# Won                           769
# Lost                          591
# Tied                           42
# Pct.                        0.563
# First NFL Season             1920
# Division                NFC North
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#    Rank                  Team  ...   Division         Stadium
# 0     1        Dallas Cowboys  ...   NFC East  Levi's Stadium
# 1     2     Green Bay Packers  ...  NFC North  Levi's Stadium
# 2     3  New England Patriots  ...   AFC East  Levi's Stadium
# 3     4         Chicago Bears  ...  NFC North  Levi's Stadium
# 4     5      Baltimore Ravens  ...  AFC North  Levi's Stadium
# 5     6        Miami Dolphins  ...   AFC East  Levi's Stadium
#
# [6 rows x 10 columns]

# %%
nfl_frame['Stadium'] = np.arange(6)

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  ...  First NFL Season   Division  Stadium
# 0     1        Dallas Cowboys    914  ...              1960   NFC East        0
# 1     2     Green Bay Packers  1,368  ...              1921  NFC North        1
# 2     3  New England Patriots    916  ...              1960   AFC East        2
# 3     4         Chicago Bears  1,402  ...              1920  NFC North        3
# 4     5      Baltimore Ravens    384  ...              1996  AFC North        4
# 5     6        Miami Dolphins    832  ...              1966   AFC East        5
#
# [6 rows x 10 columns]

# %%
stadiums = Series(["Livi's stadium", 'AT&T stadium'], index=[4,0])

# %%
stadiums
# Out:
# 4    Livi's stadium
# 0      AT&T stadium
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums

# %%
nfl_frame
# Out:
#    Rank                  Team  ...   Division         Stadium
# 0     1        Dallas Cowboys  ...   NFC East    AT&T stadium
# 1     2     Green Bay Packers  ...  NFC North             NaN
# 2     3  New England Patriots  ...   AFC East             NaN
# 3     4         Chicago Bears  ...  NFC North             NaN
# 4     5      Baltimore Ravens  ...  AFC North  Livi's stadium
# 5     6        Miami Dolphins  ...   AFC East             NaN
#
# [6 rows x 10 columns]

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#    Rank                  Team     GP  ...   Pct.  First NFL Season   Division
# 0     1        Dallas Cowboys    914  ...  0.572              1960   NFC East
# 1     2     Green Bay Packers  1,368  ...  0.567              1921  NFC North
# 2     3  New England Patriots    916  ...  0.564              1960   AFC East
# 3     4         Chicago Bears  1,402  ...  0.563              1920  NFC North
# 4     5      Baltimore Ravens    384  ...  0.559              1996  AFC North
# 5     6        Miami Dolphins    832  ...  0.552              1966   AFC East
#
# [6 rows x 9 columns]

# %%
data = {'City':['SF','LA','NYC'], 'Population':[837000,3880000,8400000]}

# %%
data
# Out:
# {'City': ['SF', 'LA', 'NYC'], 'Population': [837000, 3880000, 8400000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000
